# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Import Dependency

# %%
# !pip install scikit-learn matplotlib
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\documents\wiwie\projects\ai-fifa-21-pro-player-classifier\.venv\lib\site-packages (from scikit-learn) (2.1.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.54.1-cp313-cp313-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.7-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\documents\wiwie\projects\ai-fifa-21-pro-player-classifier\.venv\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.0.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\documents\wiwie\projects\ai-fifa-21-pro-player-classifier\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\documents\wiwie\projects\ai-fifa-21-pro-player-classifier\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading scikit_learn-1.5.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 9.7 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 9.1 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 8.8 MB/s eta 0:00:00
# Using cached matplotlib-3.9.2-cp313-cp313-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp313-cp313-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.54.1-cp313-cp313-win_amd64.whl (2.2 MB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.7-cp313-cp313-win_amd64.whl (55 kB)
# Using cached pillow-11.0.0-cp313-cp313-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    - -------------------------------------- 1.3/44.5 MB 6.7 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/44.5 MB 6.5 MB/s eta 0:00:07
#    --- ------------------------------------ 3.9/44.5 MB 6.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.0/44.5 MB 6.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.8/44.5 MB 5.6 MB/s eta 0:00:07
#    ------ --------------------------------- 6.8/44.5 MB 5.5 MB/s eta 0:00:07
#    ------- -------------------------------- 8.1/44.5 MB 5.5 MB/s eta 0:00:07
#    -------- ------------------------------- 9.7/44.5 MB 5.7 MB/s eta 0:00:07
#    --------- ------------------------------ 11.0/44.5 MB 5.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.1/44.5 MB 5.7 MB/s eta 0:00:06
#    ------------ --------------------------- 13.6/44.5 MB 5.8 MB/s eta 0:00:06
#    ------------- -------------------------- 15.2/44.5 MB 5.9 MB/s eta 0:00:05
#    -------------- ------------------------- 16.5/44.5 MB 5.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 17.8/44.5 MB 5.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 19.4/44.5 MB 6.0 MB/s eta 0:00:05
#    ------------------ --------------------- 20.7/44.5 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 22.3/44.5 MB 6.1 MB/s eta 0:00:04
#    --------------------- ------------------ 23.6/44.5 MB 6.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 25.2/44.5 MB 6.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 26.5/44.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------ --------------- 27.8/44.5 MB 6.2 MB/s eta 0:00:03
#    -------------------------- ------------- 29.4/44.5 MB 6.2 MB/s eta 0:00:03
#    --------------------------- ------------ 30.7/44.5 MB 6.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 32.0/44.5 MB 6.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 33.3/44.5 MB 6.2 MB/s eta 0:00:02
#    ------------------------------- -------- 34.9/44.5 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 36.7/44.5 MB 6.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.0/44.5 MB 6.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/44.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 40.4/44.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.5 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/44.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 6.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0 pyparsing-3.2.0 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath('../../..'))
from utils import pandas_column_utils
from utils import array_utils

# %% [markdown]
# ## Import Feature Created Dataset

# %%
url = '../../../datasets/preprocessed/ft_created.csv'
feature_created_fifa_df = pd.read_csv(url, low_memory=False)

feature_selected_fifa_df = feature_created_fifa_df

# %% [markdown]
# ## Select Relevant Feature

# %% [markdown]
# ### Check Feature

# %%
feature_selected_fifa_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Potential',
#        'Club', 'Club Logo', 'Value (€)', 'Wage (€)', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height (m)',
#        'Weight (kg)', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'FK Accuracy',
#        'Long Passing', 'Ball Control', 'Acceleration', 'Sprint Speed',
#        'Agility', 'Reactions', 'Balance', 'Shot Power', 'Jumping', 'Stamina',
#        'Strength', 'Long Shots', 'Aggression', 'Interceptions', 'Positioning',
#        'Vision', 'Penalties', 'Composure', 'Standing Tackle', 'Sliding Tackle',
#        'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning',
#        'GK Reflexes', 'Best Position', 'Best Overall Rating',
#        'Release Clause (€)', 'Defensive Awareness', 'Encoded Preferred Foot',
#        'Offensive Work Rate', 'Encoded Offensive Work Rate',
#        'Defensive Work Rate', 'Encoded Defensive Work Rate',
#        'Encoded Real Face', 'Encoded Position', 'Encoded Best Position',
#        'Good Player', 'Potential Normalized', 'Potential Value',
#        'Skill Score Total', 'Physical Score Total', 'Defensive Score Total',
#        'Attacking Score Total', 'Goalkeeper Score Total',
#        'Skill to Experience Ratio', 'Body Mass Index'],
#       dtype='object')

# %% [markdown]
# NOTE:
# 1. Removing Irrelevant Feature
#
#     (ID, Name, Photo, Club Logo, Flag, Real Face, Encoded Real Face)
# 2. Handling High Cardinality Categorical Feature
# 3. Removing The Original Feature That Already Encoded

# %% [markdown]
# ### Remove Irrelevant Feature

# %%
# TODO: Remove potential leakage (Best Overall Rating, Best Position)

# %%
feature_selected_fifa_df = feature_selected_fifa_df.drop(
    columns=[
        'ID',
        'Name',
        'Photo',
        'Club Logo',
        'Flag',
        'Real Face',
        'Encoded Real Face',
    ]
)

feature_selected_fifa_df.head(2)
# Out:
#     Age Nationality  Potential             Club     Value (€)      Wage (€)  \
# 0  33.0     Uruguay  87.000000  Atlético Madrid  1.869589e+07  73807.945008
# 1  29.0     Belgium  89.768582  Manchester City  1.869589e+07  73807.945008
#
#    Special Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0   2316.0          Right                  2.514853        4.0          3.0
# 1   2304.0          Right                  2.514853        5.0          4.0
#
#       Work Rate             Body Type Position  Jersey Number  Joined  \
# 0  High/ Medium  PLAYER_BODY_TYPE_374       RS            9.0    2020
# 1    High/ High  PLAYER_BODY_TYPE_321      RCM           17.0    2015
#
#    Contract Valid Until  Height (m)  Weight (kg)  Crossing  Finishing  \
# 0                  2022      1.8288    86.182480      80.0       92.0
# 1                  2023      1.8034    69.853168      94.0       82.0
#
#    Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  FK Accuracy  \
# 0              84.0           83.0     90.0       84.0   86.0         82.0
# 1              55.0           94.0     82.0       88.0   85.0         83.0
#
#    Long Passing  Ball Control  Acceleration  Sprint Speed  Agility  Reactions  \
# 0          77.0          84.0          72.0          68.0     76.0  90.321591
# 1          93.0          92.0          77.0          76.0     78.0  90.321591
#
#    Balance  Shot Power  Jumping  Stamina  Strength  Long Shots  Aggression  \
# 0     78.0        89.0     69.0     78.0      85.0        88.0        87.0
# 1     76.0        91.0     63.0     89.0      74.0        91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Standing Tackle  \
# 0           41.0         91.0    84.0       83.0       85.0             45.0
# 1           66.0         88.0    94.0       84.0       91.0             65.0
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0            38.0       27.0         25.0        31.0            33.0
# 1            53.0       15.0         13.0         5.0            10.0
#
#    GK Reflexes Best Position  Best Overall Rating  Release Clause (€)  \
# 0         37.0            ST            87.000000          64599999.0
# 1         13.0           CAM            88.073376         161000000.0
#
#    Defensive Awareness  Encoded Preferred Foot Offensive Work Rate  \
# 0                 57.0                       1                High
# 1                 68.0                       1                High
#
#    Encoded Offensive Work Rate Defensive Work Rate  \
# 0                          3.0              Medium
# 1                          3.0                High
#
#    Encoded Defensive Work Rate  Encoded Position  Encoded Best Position  \
# 0                          2.0               3.0                      3
# 1                          3.0               2.0                      2
#
#    Good Player  Potential Normalized  Potential Value  Skill Score Total  \
# 0            1              0.969159     1.811928e+07              842.0
# 1            1              1.000000     1.869589e+07              848.0
#
#    Physical Score Total  Defensive Score Total  Attacking Score Total  \
# 0                 526.0                  353.0                  866.0
# 1                 533.0                  402.0                  878.0
#
#    Goalkeeper Score Total  Skill to Experience Ratio  Body Mass Index
# 0                   153.0                  25.515144        25.768347
# 1                    56.0                  29.241369        21.478402

# %% [markdown]
# ### Handle High Cardinality Categorical Feature

# %%
# TODO: Handling high cardinality feature (Club, Nationality)
# We can use some method to minimize the cardinality size
# Available method:
# 1. Target encoding,
# 2. Frequency or count encoding,
# 3. Label encoding,
# 4. one-hot encoding,
# 5. grouping encoding, etc.

# %%
le = LabelEncoder()
feature_selected_fifa_df['Encoded Body Type'] = le.fit_transform(feature_selected_fifa_df['Body Type'])

feature_selected_fifa_df.head(2)
# Out:
#     Age Nationality  Potential             Club     Value (€)      Wage (€)  \
# 0  33.0     Uruguay  87.000000  Atlético Madrid  1.869589e+07  73807.945008
# 1  29.0     Belgium  89.768582  Manchester City  1.869589e+07  73807.945008
#
#    Special Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0   2316.0          Right                  2.514853        4.0          3.0
# 1   2304.0          Right                  2.514853        5.0          4.0
#
#       Work Rate             Body Type Position  Jersey Number  Joined  \
# 0  High/ Medium  PLAYER_BODY_TYPE_374       RS            9.0    2020
# 1    High/ High  PLAYER_BODY_TYPE_321      RCM           17.0    2015
#
#    Contract Valid Until  Height (m)  Weight (kg)  Crossing  Finishing  \
# 0                  2022      1.8288    86.182480      80.0       92.0
# 1                  2023      1.8034    69.853168      94.0       82.0
#
#    Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  FK Accuracy  \
# 0              84.0           83.0     90.0       84.0   86.0         82.0
# 1              55.0           94.0     82.0       88.0   85.0         83.0
#
#    Long Passing  Ball Control  Acceleration  Sprint Speed  Agility  Reactions  \
# 0          77.0          84.0          72.0          68.0     76.0  90.321591
# 1          93.0          92.0          77.0          76.0     78.0  90.321591
#
#    Balance  Shot Power  Jumping  Stamina  Strength  Long Shots  Aggression  \
# 0     78.0        89.0     69.0     78.0      85.0        88.0        87.0
# 1     76.0        91.0     63.0     89.0      74.0        91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Standing Tackle  \
# 0           41.0         91.0    84.0       83.0       85.0             45.0
# 1           66.0         88.0    94.0       84.0       91.0             65.0
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0            38.0       27.0         25.0        31.0            33.0
# 1            53.0       15.0         13.0         5.0            10.0
#
#    GK Reflexes Best Position  Best Overall Rating  Release Clause (€)  \
# 0         37.0            ST            87.000000          64599999.0
# 1         13.0           CAM            88.073376         161000000.0
#
#    Defensive Awareness  Encoded Preferred Foot Offensive Work Rate  \
# 0                 57.0                       1                High
# 1                 68.0                       1                High
#
#    Encoded Offensive Work Rate Defensive Work Rate  \
# 0                          3.0              Medium
# 1                          3.0                High
#
#    Encoded Defensive Work Rate  Encoded Position  Encoded Best Position  \
# 0                          2.0               3.0                      3
# 1                          3.0               2.0                      2
#
#    Good Player  Potential Normalized  Potential Value  Skill Score Total  \
# 0            1              0.969159     1.811928e+07              842.0
# 1            1              1.000000     1.869589e+07              848.0
#
#    Physical Score Total  Defensive Score Total  Attacking Score Total  \
# 0                 526.0                  353.0                  866.0
# 1                 533.0                  402.0                  878.0
#
#    Goalkeeper Score Total  Skill to Experience Ratio  Body Mass Index  \
# 0                   153.0                  25.515144        25.768347
# 1                    56.0                  29.241369        21.478402
#
#    Encoded Body Type
# 0                115
# 1                 69

# %%
feature_selected_fifa_df = feature_selected_fifa_df.drop(
    columns=[
        'Club',
        'Nationality',
    ]
)

feature_selected_fifa_df.head(2)
# Out:
#     Age  Potential     Value (€)      Wage (€)  Special Preferred Foot  \
# 0  33.0  87.000000  1.869589e+07  73807.945008   2316.0          Right
# 1  29.0  89.768582  1.869589e+07  73807.945008   2304.0          Right
#
#    International Reputation  Weak Foot  Skill Moves     Work Rate  \
# 0                  2.514853        4.0          3.0  High/ Medium
# 1                  2.514853        5.0          4.0    High/ High
#
#               Body Type Position  Jersey Number  Joined  Contract Valid Until  \
# 0  PLAYER_BODY_TYPE_374       RS            9.0    2020                  2022
# 1  PLAYER_BODY_TYPE_321      RCM           17.0    2015                  2023
#
#    Height (m)  Weight (kg)  Crossing  Finishing  Heading Accuracy  \
# 0      1.8288    86.182480      80.0       92.0              84.0
# 1      1.8034    69.853168      94.0       82.0              55.0
#
#    Short Passing  Volleys  Dribbling  Curve  FK Accuracy  Long Passing  \
# 0           83.0     90.0       84.0   86.0         82.0          77.0
# 1           94.0     82.0       88.0   85.0         83.0          93.0
#
#    Ball Control  Acceleration  Sprint Speed  Agility  Reactions  Balance  \
# 0          84.0          72.0          68.0     76.0  90.321591     78.0
# 1          92.0          77.0          76.0     78.0  90.321591     76.0
#
#    Shot Power  Jumping  Stamina  Strength  Long Shots  Aggression  \
# 0        89.0     69.0     78.0      85.0        88.0        87.0
# 1        91.0     63.0     89.0      74.0        91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Standing Tackle  \
# 0           41.0         91.0    84.0       83.0       85.0             45.0
# 1           66.0         88.0    94.0       84.0       91.0             65.0
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0            38.0       27.0         25.0        31.0            33.0
# 1            53.0       15.0         13.0         5.0            10.0
#
#    GK Reflexes Best Position  Best Overall Rating  Release Clause (€)  \
# 0         37.0            ST            87.000000          64599999.0
# 1         13.0           CAM            88.073376         161000000.0
#
#    Defensive Awareness  Encoded Preferred Foot Offensive Work Rate  \
# 0                 57.0                       1                High
# 1                 68.0                       1                High
#
#    Encoded Offensive Work Rate Defensive Work Rate  \
# 0                          3.0              Medium
# 1                          3.0                High
#
#    Encoded Defensive Work Rate  Encoded Position  Encoded Best Position  \
# 0                          2.0               3.0                      3
# 1                          3.0               2.0                      2
#
#    Good Player  Potential Normalized  Potential Value  Skill Score Total  \
# 0            1              0.969159     1.811928e+07              842.0
# 1            1              1.000000     1.869589e+07              848.0
#
#    Physical Score Total  Defensive Score Total  Attacking Score Total  \
# 0                 526.0                  353.0                  866.0
# 1                 533.0                  402.0                  878.0
#
#    Goalkeeper Score Total  Skill to Experience Ratio  Body Mass Index  \
# 0                   153.0                  25.515144        25.768347
# 1                    56.0                  29.241369        21.478402
#
#    Encoded Body Type
# 0                115
# 1                 69

# %% [markdown]
# ### Remove The Original Feature That Already Encoded

# %%
feature_selected_fifa_df = feature_selected_fifa_df.drop(
    columns=[
        'Preferred Foot',
        'Work Rate',
        'Position',
        'Best Position',
        'Offensive Work Rate',
        'Defensive Work Rate',
        'Body Type',
    ]
)

feature_selected_fifa_df.head(2)
# Out:
#     Age  Potential     Value (€)      Wage (€)  Special  \
# 0  33.0  87.000000  1.869589e+07  73807.945008   2316.0
# 1  29.0  89.768582  1.869589e+07  73807.945008   2304.0
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Joined  \
# 0                  2.514853        4.0          3.0            9.0    2020
# 1                  2.514853        5.0          4.0           17.0    2015
#
#    Contract Valid Until  Height (m)  Weight (kg)  Crossing  Finishing  \
# 0                  2022      1.8288    86.182480      80.0       92.0
# 1                  2023      1.8034    69.853168      94.0       82.0
#
#    Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  FK Accuracy  \
# 0              84.0           83.0     90.0       84.0   86.0         82.0
# 1              55.0           94.0     82.0       88.0   85.0         83.0
#
#    Long Passing  Ball Control  Acceleration  Sprint Speed  Agility  Reactions  \
# 0          77.0          84.0          72.0          68.0     76.0  90.321591
# 1          93.0          92.0          77.0          76.0     78.0  90.321591
#
#    Balance  Shot Power  Jumping  Stamina  Strength  Long Shots  Aggression  \
# 0     78.0        89.0     69.0     78.0      85.0        88.0        87.0
# 1     76.0        91.0     63.0     89.0      74.0        91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Standing Tackle  \
# 0           41.0         91.0    84.0       83.0       85.0             45.0
# 1           66.0         88.0    94.0       84.0       91.0             65.0
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0            38.0       27.0         25.0        31.0            33.0
# 1            53.0       15.0         13.0         5.0            10.0
#
#    GK Reflexes  Best Overall Rating  Release Clause (€)  Defensive Awareness  \
# 0         37.0            87.000000          64599999.0                 57.0
# 1         13.0            88.073376         161000000.0                 68.0
#
#    Encoded Preferred Foot  Encoded Offensive Work Rate  \
# 0                       1                          3.0
# 1                       1                          3.0
#
#    Encoded Defensive Work Rate  Encoded Position  Encoded Best Position  \
# 0                          2.0               3.0                      3
# 1                          3.0               2.0                      2
#
#    Good Player  Potential Normalized  Potential Value  Skill Score Total  \
# 0            1              0.969159     1.811928e+07              842.0
# 1            1              1.000000     1.869589e+07              848.0
#
#    Physical Score Total  Defensive Score Total  Attacking Score Total  \
# 0                 526.0                  353.0                  866.0
# 1                 533.0                  402.0                  878.0
#
#    Goalkeeper Score Total  Skill to Experience Ratio  Body Mass Index  \
# 0                   153.0                  25.515144        25.768347
# 1                    56.0                  29.241369        21.478402
#
#    Encoded Body Type
# 0                115
# 1                 69

# %%
feature_selected_fifa_df.shape
# Out:
# (17108, 65)

# %%
parseable_to_int_columns = [col for col in feature_selected_fifa_df.columns if pandas_column_utils.parseable_to_int(feature_selected_fifa_df[col])]
rest_columns = array_utils.subtract(feature_selected_fifa_df.columns, parseable_to_int_columns)

feature_selected_fifa_df[parseable_to_int_columns] = feature_selected_fifa_df[parseable_to_int_columns].astype('Int64')
feature_selected_fifa_df[rest_columns] = feature_selected_fifa_df[rest_columns].astype('float64')

feature_selected_fifa_df.head(2)
# Out:
#     Age  Potential     Value (€)      Wage (€)  Special  \
# 0  33.0  87.000000  1.869589e+07  73807.945008   2316.0
# 1  29.0  89.768582  1.869589e+07  73807.945008   2304.0
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Joined  \
# 0                  2.514853          4          3.0              9    2020
# 1                  2.514853          5          4.0             17    2015
#
#    Contract Valid Until  Height (m)  Weight (kg)  Crossing  Finishing  \
# 0                  2022      1.8288    86.182480        80         92
# 1                  2023      1.8034    69.853168        94         82
#
#    Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  FK Accuracy  \
# 0                84           83.0     90.0         84   86.0           82
# 1                55           94.0     82.0         88   85.0           83
#
#    Long Passing  Ball Control  Acceleration  Sprint Speed  Agility  Reactions  \
# 0          77.0          84.0          72.0          68.0       76  90.321591
# 1          93.0          92.0          77.0          76.0       78  90.321591
#
#    Balance  Shot Power  Jumping  Stamina  Strength  Long Shots  Aggression  \
# 0       78        89.0       69     78.0      85.0          88          87
# 1       76        91.0       63     89.0      74.0          91          76
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Standing Tackle  \
# 0           41.0           91      84         83         85               45
# 1           66.0           88      94         84         91               65
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0            38.0       27.0         25.0        31.0            33.0
# 1            53.0       15.0         13.0         5.0            10.0
#
#    GK Reflexes  Best Overall Rating  Release Clause (€)  Defensive Awareness  \
# 0         37.0            87.000000            64599999                 57.0
# 1         13.0            88.073376           161000000                 68.0
#
#    Encoded Preferred Foot  Encoded Offensive Work Rate  \
# 0                       1                            3
# 1                       1                            3
#
#    Encoded Defensive Work Rate  Encoded Position  Encoded Best Position  \
# 0                            2                 3                      3
# 1                            3                 2                      2
#
#    Good Player  Potential Normalized  Potential Value  Skill Score Total  \
# 0            1              0.969159     1.811928e+07              842.0
# 1            1              1.000000     1.869589e+07              848.0
#
#    Physical Score Total  Defensive Score Total  Attacking Score Total  \
# 0                 526.0                  353.0                  866.0
# 1                 533.0                  402.0                  878.0
#
#    Goalkeeper Score Total  Skill to Experience Ratio  Body Mass Index  \
# 0                   153.0                  25.515144        25.768347
# 1                    56.0                  29.241369        21.478402
#
#    Encoded Body Type
# 0                115
# 1                 69

# %% [markdown]
# ### Identify Strong Predictors

# %% [markdown]
# NOTE:
# 1. Player attributes
#
#     (Age, Potential, Value (€), Wage (€))
# 2. Performance score
#
#     (Skill Score Total, Physical Score Total, Defensive Score Total, Attacking Score Total, Goalkeeper Score Total)
# 3. Technical and physical attributes
#
#     (Crossing, Finishing, Dribbling, Ball Control, Acceleration, Sprint Speed, Agility, Composure, Stamina)
# 4. Experience and value indicators
#
#     (Skill to Experience Ratio, Body Mass Index)
# 5. Positional and role-based features
#
#     (Encoded Position, Encoded Best Position)
# 6. Contractual information
#
#     (Release Clause  (€))

# %% [markdown]
# ### Check Features Correlation

# %%
correlation_matrix = feature_selected_fifa_df.corr()

pd.set_option('display.max_rows', None)

target_correlation = correlation_matrix['Good Player'].sort_values(ascending=False)
print(target_correlation)

pd.reset_option('display.max_rows')
# Out:
# Good Player                    1.000000
# Value (€)                      0.773530
# Potential Value                0.765345
# Wage (€)                       0.671703
# Best Overall Rating            0.630132
# Release Clause (€)             0.622936
# Reactions                      0.566445
# International Reputation       0.508098
# Potential                      0.507391
# Potential Normalized           0.507391
# Composure                      0.430260
# Special                        0.368552
# Vision                         0.346692
# Shot Power                     0.334028
# Short Passing                  0.304477
# Long Passing                   0.297577
# Skill Score Total              0.271720
# Attacking Score Total          0.269137
# Age                            0.258722
# Ball Control                   0.257218
# Curve                          0.250638
# Volleys                        0.234354
# Long Shots                     0.232510
# FK Accuracy                    0.228269
# Crossing                       0.224427
# Skill Moves                    0.222274
# Aggression                     0.218192
# Dribbling                      0.211345
# Positioning                    0.208498
# Penalties                      0.202182
# Finishing                      0.190263
# Defensive Score Total          0.187265
# Interceptions                  0.181924
# Heading Accuracy               0.172301
# Physical Score Total           0.172269
# Stamina                        0.170938
# Strength                       0.168100
# Defensive Awareness            0.164625
# Jumping                        0.144445
# Standing Tackle                0.142194
# Weak Foot                      0.133717
# Sliding Tackle                 0.125917
# Agility                        0.121600
# Encoded Offensive Work Rate    0.109859
# Body Mass Index                0.095689
# Weight (kg)                    0.086965
# Sprint Speed                   0.083426
# Skill to Experience Ratio      0.079048
# Acceleration                   0.077561
# Encoded Defensive Work Rate    0.071792
# Balance                        0.063443
# Encoded Body Type              0.054810
# GK Kicking                     0.033630
# Height (m)                     0.029997
# Goalkeeper Score Total         0.027810
# GK Positioning                 0.027045
# GK Handling                    0.026653
# GK Reflexes                    0.025403
# GK Diving                      0.024514
# Encoded Preferred Foot        -0.004121
# Encoded Best Position         -0.006305
# Joined                        -0.011598
# Contract Valid Until          -0.061253
# Jersey Number                 -0.099547
# Encoded Position              -0.165008
# Name: Good Player, dtype: float64

# %%
x = feature_selected_fifa_df['Value (€)'].values
y = feature_selected_fifa_df['Good Player'].values

plt.scatter(x, y)
plt.xlabel('Value (€)')
plt.ylabel('Good Player')
plt.title('Value (€) vs Good Player')
plt.show()

# %% [markdown]
# NOTE:
# 1. Get feature with correlation > 50%

# %%
high_medium_correlated_features = target_correlation[target_correlation > 0.5].index

# %% [markdown]
# ### Feature Importance

# %%
# TODO: Use tree-based models (Random Forest, Gradient Boosting) to evaluate the importance of each feature

# %% [markdown]
# ### Domain Knowledge

# %%
# TODO: Use understanding in the domain

# %% [markdown]
# ### Select Feature

# %%
feature_selected_fifa_df = feature_selected_fifa_df[[*high_medium_correlated_features]]

feature_selected_fifa_df.head(2)
# Out:
#    Good Player     Value (€)  Potential Value      Wage (€)  \
# 0            1  1.869589e+07     1.811928e+07  73807.945008
# 1            1  1.869589e+07     1.869589e+07  73807.945008
#
#    Best Overall Rating  Release Clause (€)  Reactions  \
# 0            87.000000            64599999  90.321591
# 1            88.073376           161000000  90.321591
#
#    International Reputation  Potential  Potential Normalized
# 0                  2.514853  87.000000              0.969159
# 1                  2.514853  89.768582              1.000000

# %% [markdown]
# ## Export Feature Selected Dataset

# %%
feature_selected_fifa_df.to_csv('../../../datasets/preprocessed/ft_selected.csv', index=False)
feature_selected_fifa_df.to_csv('../../../datasets/processed/processed.csv', index=False)
